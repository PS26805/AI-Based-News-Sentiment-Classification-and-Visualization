# %%
# !pip install requests beautifulsoup4 pandas textblob matplotlib wordcloud
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000205865574D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/textblob/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020586582FD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/textblob/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020586583250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/textblob/
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

print("Everything is working!")
# Out:
# Everything is working!

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from textblob import TextBlob
#       3 import matplotlib.pyplot as plt
#       4 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'textblob'

# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ------------------------------- ------ 524.3/625.0 kB 407.8 kB/s eta 0:00:01
#    ------------------------------- ------ 524.3/625.0 kB 407.8 kB/s eta 0:00:01
#    ---------------------------------------- 625.0/625.0 kB 390.6 kB/s  0:00:02
# ...

# %%
from textblob import TextBlob

print("TextBlob is working!")
# Out:
# TextBlob is working!

# %%
# !pip install wordcloud

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud

print("Everything is working!")
# Out:
# Everything is working!

# %%
import pandas as pd

file_id = "16vUX3V7p80oa5MbJiQRNup2OGIDZln6r"
url = f"https://drive.google.com/uc?export=download&id={file_id}"

df = pd.read_csv(url)

print(df.shape)
df.head()
# Out:
# (209527, 8)
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Asus

# %%
import os

print(os.listdir())
# Out:
# ['.anaconda', '.arduinoIDE', '.conda', '.continuum', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.ms-ad', '.spyder-py3', '.vscode', '1stimageproject.py', '2ndpr.ipynb', 'anaconda3', 'AppData', 'Application Data', 'basic2.ipynb', 'Contacts', 'Cookies', 'demo.py', 'Documents', 'Downloads', 'Favorites', 'Jedi', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{46dd5509-a47d-11f0-92a9-50bbb50d7cbb}.TM.blf', 'NTUSER.DAT{46dd5509-a47d-11f0-92a9-50bbb50d7cbb}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{46dd5509-a47d-11f0-92a9-50bbb50d7cbb}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'pallavi.txt', 'pallu2.ipynb', 'pallupy', 'patil.txt', 'pp3.py', 'ppimage.py', 'ppimage2.py', 'practice.txt', 'PrintHood', 'pythonbasic.ipynb', 'Recent', 'sample.txt', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'stringlist.ipynb', 'Templates', 'Untitled.ipynb', 'Untitle
# ...

# %%
import os

for root, dirs, files in os.walk("C:/Users/Asus"):
    for file in files:
        if file.endswith(".json"):
            print(os.path.join(root, file))
# Out:
# C:/Users/Asus\.arduinoIDE\recentworkspace.json
# C:/Users/Asus\.arduinoIDE\settings.json
# C:/Users/Asus\.arduinoIDE\localization-cache\bg\nls.config.bg.json
# C:/Users/Asus\.arduinoIDE\localization-cache\cs\nls.config.cs.json
# C:/Users/Asus\.arduinoIDE\localization-cache\de\nls.config.de.json
# C:/Users/Asus\.arduinoIDE\localization-cache\es\nls.config.es.json
# C:/Users/Asus\.arduinoIDE\localization-cache\fr\nls.config.fr.json
# C:/Users/Asus\.arduinoIDE\localization-cache\hu\nls.config.hu.json
# C:/Users/Asus\.arduinoIDE\localization-cache\it\nls.config.it.json
# C:/Users/Asus\.arduinoIDE\localization-cache\ja\nls.config.ja.json
# C:/Users/Asus\.arduinoIDE\localization-cache\ko\nls.config.ko.json
# C:/Users/Asus\.arduinoIDE\localization-cache\nl\nls.config.nl.json
# C:/Users/Asus\.arduinoIDE\localization-cache\pl\nls.config.pl.json
# C:/Users/Asus\.arduinoIDE\localization-cache\pt-br\nls.config.pt-br.json
# C:/Users/Asus\.arduinoIDE\localization-cache\ru\nls.config.ru.json
# ...

# %%
import os

downloads = r"C:\Users\Asus\Downloads"

for root, dirs, files in os.walk(downloads):
    for file in files:
        if file.endswith(".json"):
            print(os.path.join(root, file))

# %%
import pandas as pd

df = pd.read_json(
    r"C:\Users\Asus\Downloads\archive\News_Category_Dataset_v3.json",
    lines=True
)

print(df.shape)
df.head()
# Out:
# (209527, 6)
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
print(df.columns)
# Out:
# Index(['link', 'headline', 'category', 'short_description', 'authors', 'date'], dtype='object')

# %%
print(df.shape)
# Out:
# (209527, 6)

# %%
df=df[['headline','category']]
print(df.shape)
# Out:
# (209527, 2)

# %%
from textblob import TextBlob

def get_sentiment(text):
    polarity = TextBlob(str(text)).sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df['Sentiment'] =df['headline'].apply(get_sentiment)

# %%
print(df['sentiment'].value_counts())
# Out:
# sentiment
# Neutral     109586
# Positive     68204
# Negative     31737
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Sentiment'].value_counts().plot(kind='bar')

plt.title("Sentiment Analysis of News Headlines")
plt.xlabel("Sentiment")
plt.ylabel("Number of Headlines")

plt.show()

# %%
df['Sentiment'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title("Sentiment Distribution")
plt.ylabel('')

plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df['headline'].astype(str))

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white'
).generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
df.to_csv("News_Sentiment_Analysis.csv", index=False)

print("CSV Saved Successfully")
# Out:
# CSV Saved Successfully

# %%
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
import os
print(os.path.exists("News_Sentiment_Analysis.csv"))
# Out:
# True

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Asus

# %%
import os
print("News_Sentiment_Analysis.csv" in os.listdir())
# Out:
# True
